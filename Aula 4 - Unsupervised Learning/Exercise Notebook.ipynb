# %% [markdown]
# # Class 4: Exercise Notebook - Unsupervised Learning

# %% [markdown]
# ## Dataset: Pima Indians Diabetes Database
#
# Data source and documentation [here](https://www.kaggle.com/datasets/uciml/pima-indians-diabetes-database?resource=download&select=diabetes.csv)
#
# Data summary:
# | **Column**                 | **Description**                                                        |
# |----------------------------|------------------------------------------------------------------------|
# | **Pregnancies**            | Number of times pregnant                                               |
# | **Glucose**                | Plasma glucose concentration a 2 hours in an oral glucose tolerance test|
# | **BloodPressure**          | Diastolic blood pressure (mm Hg)                                       |
# | **SkinThickness**          | Triceps skin fold thickness (mm)                                       |
# | **Insulin**                | 2-Hour serum insulin (mu U/ml)                                         |
# | **BMI**                    | Body mass index (weight in kg/(height in m)^2)                         |
# | **DiabetesPedigreeFunction** | Diabetes pedigree function                                           |
# | **Age**                    | Age (years)                                                            |
# | **Outcome**                | Class variable (0 or 1) 268 of 768 are 1, the others are 0             |

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Data

# %%
# In google colab you may need to add the csv file to the files folder --> you can download it from the folder "data"
data = pd.read_csv('https://raw.githubusercontent.com/Hospital-Da-Luz-Learning-Health/MLCatolica24/main/Aula%204%20-%20Unsupervised%20Learning/data/diabetes.csv')

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# dataframe shape
data.shape
# Out:
# (768, 9)

# %%
# check missing values
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# ## EDA

# %% [markdown]
# Let's check how the dataset looks like -> This can be an example of how to explore the variables

# %%
hists = data.hist(bins=35, figsize=(15,15))
plt.show()

# %%
# Separate features and labels
X = data.drop('Outcome', axis=1)

# %% [markdown]
# ### Standardize the dataset

# %%
# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## K-means

# %% [markdown]
# ### Exercise 1:
#
# Determine the optimal number of clusters using the elbow method.
#
# **Note:** This is a real dataset, you may not find a clear "elbow point"!

# %%
# Define the range of k values to test
#k_values = ...
#inertia_values = []

# %%
# Compute K-Means clustering and calculate inertia for each k
#for k in k_values:
#    ...

# %%
# Plotting the Elbow Method
plt.figure(figsize=(6, 4))
#plt.plot(k_values, inertia_values, marker='o')
#plt.xlabel('Number of clusters (k)')
#plt.ylabel('Inertia')
#plt.title('Elbow Method for Optimal k')
#plt.grid(True)
plt.show()

# %% [markdown]
# ### Exercise 2:
#
# Calculate the silhouette score for the optimal number of clusters (the k you achieved before)

# %%
# Fit K-Means for k clusters
#kmeans = KMeans(...
#cluster_labels = ...

# %%
# Compute silhouette scores and samples
#silhouette_avg = ...
#silhouette_avg

# %% [markdown]
# ### Exercise 3:
#
# Apply the PCA fro 2 dimensions and plot the data for the optimal number of clusters

# %%
# Apply clustering algortihm ir use what is already done in the previous exercise
# cluster_labels = ...

# %%
# Apply PCA to reduce dimensions to 2
#pca = PCA(...
#data_pca = ...

# %%
# Create a DataFrame with PCA components and cluster labels
pca_df = pd.DataFrame(data=data_pca, columns=['PCA1', 'PCA2'])
#pca_df['Cluster'] = ...

# %%
# Plot the data
plt.figure(figsize=(10, 6))
#sns.scatterplot(x='PCA1', y='PCA2', hue='Cluster', palette='viridis', data=pca_df, legend='full')
#plt.title('PCA of Pima Indians Diabetes Dataset')
#plt.xlabel('Principal Component 1')
#plt.ylabel('Principal Component 2')
#plt.legend(title='Cluster')
#plt.grid(True)
plt.show()

# %%
# Check the explained variance by each principal component
#explained_variance_ratio = ...
print(explained_variance_ratio)

# %%
# Cumulative variance explained
#cumulative_variance = ...
print("Cumulative Variance Explained by Principal Components:", cumulative_variance[1])

# %%
# Plotting the variance explained
plt.figure(figsize=(8, 6))
#plt.bar(range(1, len(explained_variance_ratio) + 1), explained_variance_ratio, alpha=0.7, align='center', label='Individual explained variance')
#plt.step(range(1, len(cumulative_variance) + 1), cumulative_variance, where='mid', label='Cumulative explained variance')
#plt.xlabel('Principal Components')
#plt.ylabel('Explained Variance Ratio')
#plt.title('Explained Variance by Principal Components')
#plt.legend(loc='best')
#plt.grid(True)
#plt.tight_layout()
plt.show()

# %% [markdown]
# ### Exercise 4:
#
# Compute the percentage of diabetic cases per cluster for the optimal number of clusters

# %%
# Add cluster labels to the original dataframe
#data['Cluster'] = ...

# %%
# Compute the percentage of diabetic cases (Outcome == 1) per cluster
# cluster_summary = 
# cluster_summary['Percentage_heart_disease'] = ...
cluster_summary
