# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv('data/BRCA_preprocessed.csv', index_col='Patient_ID')
df.head(3)
df.shape
# Out:
# (317, 15)

# %%
df
# Out:
#                Age  Gender  Protein1  Protein2  Protein3  Protein4  \
# Patient_ID
# TCGA-D8-A1XD  36.0  FEMALE  0.080353   0.42638   0.54715  0.273680
# TCGA-EW-A1OX  43.0  FEMALE -0.420320   0.57807   0.61447 -0.031505
# TCGA-A8-A079  69.0  FEMALE  0.213980   1.31140  -0.32747 -0.234260
# TCGA-D8-A1XR  56.0  FEMALE  0.345090  -0.21147  -0.19304  0.124270
# TCGA-BH-A0BF  56.0  FEMALE  0.221550   1.90680   0.52045 -0.311990
# ...            ...     ...       ...       ...       ...       ...
# TCGA-AN-A04A  36.0  FEMALE  0.231800   0.61804  -0.55779 -0.517350
# TCGA-A8-A085  44.0    MALE  0.732720   1.11170  -0.26952 -0.354920
# TCGA-A1-A0SG  61.0  FEMALE -0.719470   2.54850  -0.15024  0.339680
# TCGA-A2-A0EU  79.0  FEMALE  0.479400   2.05590  -0.53136 -0.188480
# TCGA-B6-A40B  76.0  FEMALE -0.244270   0.92556  -0.41823 -0.067848
#
#              Tumour_Stage                       Histology ER status PR status  \
# Patient_ID
# TCGA-D8-A1XD          III   Infiltrating Ductal Carcinoma  Positive  Positive
# TCGA-EW-A1OX           II              Mucinous Carcinoma  Positive  Positive
# TCGA-A8-A079          III   Infiltrating Ductal Carcinoma  Positive  Positive
# TCGA-D8-A1XR           II   Infiltrating Ductal Carcinoma  Positive  Positive
# TCGA-BH-A0BF           II   Infiltrating Ductal Carcinoma  Positive  Positive
# ...                   ...                             ...       ...       ...
# TCGA-AN-A04A          III   Infiltrating Ductal Carcinoma  Positive  Positive
# TCGA-A8-A085           II  Infiltrating Lobular Carcinoma  Positive  Positive
# TCGA-A1-A0SG           II   Infiltrating Ductal Carcinoma  Positive  Positive
# TCGA-A2-A0EU            I   Infiltrating Ductal Carcinoma  Positive  Positive
# TCGA-B6-A40B            I   Infiltrating Ductal Carcinoma  Positive  Positive
#
#              HER2 status                 Surgery_type Date_of_Surgery  \
# Patient_ID
# TCGA-D8-A1XD    Negative  Modified Radical Mastectomy       15-Jan-17
# TCGA-EW-A1OX    Negative                   Lumpectomy       26-Apr-17
# TCGA-A8-A079    Negative                        Other       08-Sep-17
# TCGA-D8-A1XR    Negative  Modified Radical Mastectomy       25-Jan-17
# TCGA-BH-A0BF    Negative                        Other       06-May-17
# ...                  ...                          ...             ...
# TCGA-AN-A04A    Positive            Simple Mastectomy       11-Nov-19
# TCGA-A8-A085    Negative                        Other       01-Nov-19
# TCGA-A1-A0SG    Negative                   Lumpectomy       11-Nov-19
# TCGA-A2-A0EU    Positive                   Lumpectomy       21-Nov-19
# TCGA-B6-A40B    Negative                   Lumpectomy       11-Nov-19
#
#              Date_of_Last_Visit  Patient_Status
# Patient_ID
# TCGA-D8-A1XD          19-Jun-17               1
# TCGA-EW-A1OX          09-Nov-18               0
# TCGA-A8-A079          09-Jun-18               1
# TCGA-D8-A1XR          12-Jul-17               1
# TCGA-BH-A0BF          27-Jun-19               0
# ...                         ...             ...
# TCGA-AN-A04A          09-Feb-20               0
# TCGA-A8-A085          04-Mar-20               0
# TCGA-A1-A0SG          18-Jan-21               0
# TCGA-A2-A0EU          19-Feb-21               0
# TCGA-B6-A40B          05-Jan-21               0
#
# [317 rows x 15 columns]

# %%
df['Patient_Status'] = df['Patient_Status'].replace({'Alive':1, 'Dead':0})
# Out:
# /var/folders/bp/hxsq_5h96wv5hnzrf6mldthm0000gp/T/ipykernel_74651/136376414.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Patient_Status'] = df['Patient_Status'].replace({'Alive':1, 'Dead':0})

# %%
df.to_csv('data/BRCA_preprocessed.csv', index=False)

# %%
df
# Out:
#        Patient_ID   Age  Gender  Protein1  Protein2  Protein3  Protein4  \
# 0    TCGA-D8-A1XD  36.0  FEMALE  0.080353   0.42638   0.54715  0.273680
# 1    TCGA-EW-A1OX  43.0  FEMALE -0.420320   0.57807   0.61447 -0.031505
# 2    TCGA-A8-A079  69.0  FEMALE  0.213980   1.31140  -0.32747 -0.234260
# 3    TCGA-D8-A1XR  56.0  FEMALE  0.345090  -0.21147  -0.19304  0.124270
# 4    TCGA-BH-A0BF  56.0  FEMALE  0.221550   1.90680   0.52045 -0.311990
# ..            ...   ...     ...       ...       ...       ...       ...
# 312  TCGA-AN-A04A  36.0  FEMALE  0.231800   0.61804  -0.55779 -0.517350
# 313  TCGA-A8-A085  44.0    MALE  0.732720   1.11170  -0.26952 -0.354920
# 314  TCGA-A1-A0SG  61.0  FEMALE -0.719470   2.54850  -0.15024  0.339680
# 315  TCGA-A2-A0EU  79.0  FEMALE  0.479400   2.05590  -0.53136 -0.188480
# 316  TCGA-B6-A40B  76.0  FEMALE -0.244270   0.92556  -0.41823 -0.067848
#
#     Tumour_Stage                       Histology ER status PR status  \
# 0            III   Infiltrating Ductal Carcinoma  Positive  Positive
# 1             II              Mucinous Carcinoma  Positive  Positive
# 2            III   Infiltrating Ductal Carcinoma  Positive  Positive
# 3             II   Infiltrating Ductal Carcinoma  Positive  Positive
# 4             II   Infiltrating Ductal Carcinoma  Positive  Positive
# ..           ...                             ...       ...       ...
# 312          III   Infiltrating Ductal Carcinoma  Positive  Positive
# 313           II  Infiltrating Lobular Carcinoma  Positive  Positive
# 314           II   Infiltrating Ductal Carcinoma  Positive  Positive
# 315            I   Infiltrating Ductal Carcinoma  Positive  Positive
# 316            I   Infiltrating Ductal Carcinoma  Positive  Positive
#
#     HER2 status                 Surgery_type Date_of_Surgery  \
# 0      Negative  Modified Radical Mastectomy       15-Jan-17
# 1      Negative                   Lumpectomy       26-Apr-17
# 2      Negative                        Other       08-Sep-17
# 3      Negative  Modified Radical Mastectomy       25-Jan-17
# 4      Negative                        Other       06-May-17
# ..          ...                          ...             ...
# 312    Positive            Simple Mastectomy       11-Nov-19
# 313    Negative                        Other       01-Nov-19
# 314    Negative                   Lumpectomy       11-Nov-19
# 315    Positive                   Lumpectomy       21-Nov-19
# 316    Negative                   Lumpectomy       11-Nov-19
#
#     Date_of_Last_Visit  Patient_Status
# 0            19-Jun-17               1
# 1            09-Nov-18               0
# 2            09-Jun-18               1
# 3            12-Jul-17               1
# 4            27-Jun-19               0
# ..                 ...             ...
# 312          09-Feb-20               0
# 313          04-Mar-20               0
# 314          18-Jan-21               0
# 315          19-Feb-21               0
# 316          05-Jan-21               0
#
# [317 rows x 16 columns]
