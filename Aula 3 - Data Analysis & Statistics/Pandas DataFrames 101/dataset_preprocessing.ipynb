# %%
import pandas as pd

# %%
df = pd.read_csv('data/heart_disease.csv')

# %%
# preprocessing
df['sex'] = df['sex'].replace({1:"male",0:'female'})
df['cp'] = df['cp'].replace({1: 'typical angina', 2:"atypical angina", 3: 'non-anginal pain', 4:'asymptomatic'})
df['restecg'] = df['restecg'].replace({0:'normal', 1:'ST-T wave abnormality', 2: 'left ventricular hypertrophy'})
df['slope'] = df['slope'].replace({1:'upsloping', 2:'fat',3:'downsloping'})
df['thal'] = df['thal'].replace({3:'normal', 6:'fixed defect', 7:'reversible defect'})
df['Diagnosed'] = df['Diagnosed'].replace({0:'<50%', 1:'>50%'})

# %%
df
# Out:
#      age     sex                cp  trestbps  chol  fbs  \
# 0     63    male    typical angina       145   233    1
# 1     67    male      asymptomatic       160   286    0
# 2     67    male      asymptomatic       120   229    0
# 3     37    male  non-anginal pain       130   250    0
# 4     41  female   atypical angina       130   204    0
# ..   ...     ...               ...       ...   ...  ...
# 298   45    male    typical angina       110   264    0
# 299   68    male      asymptomatic       144   193    1
# 300   57    male      asymptomatic       130   131    0
# 301   57  female   atypical angina       130   236    0
# 302   38    male  non-anginal pain       138   175    0
#
#                           restecg  thalach  exang  oldpeak        slope   ca  \
# 0    left ventricular hypertrophy      150      0      2.3  downsloping  0.0
# 1    left ventricular hypertrophy      108      1      1.5          fat  3.0
# ...

# %%
df = df.reset_index()
df = df.rename(columns={'index':'id'})
df = df.sample(frac=1)
df
# Out:
#       id  age     sex                cp  trestbps  chol  fbs  \
# 0      0   63    male    typical angina       145   233    1
# 1      1   67    male      asymptomatic       160   286    0
# 2      2   67    male      asymptomatic       120   229    0
# 3      3   37    male  non-anginal pain       130   250    0
# 4      4   41  female   atypical angina       130   204    0
# ..   ...  ...     ...               ...       ...   ...  ...
# 298  298   45    male    typical angina       110   264    0
# 299  299   68    male      asymptomatic       144   193    1
# 300  300   57    male      asymptomatic       130   131    0
# 301  301   57  female   atypical angina       130   236    0
# 302  302   38    male  non-anginal pain       138   175    0
#
#                           restecg  thalach  exang  oldpeak        slope   ca  \
# 0    left ventricular hypertrophy      150      0      2.3  downsloping  0.0
# ...

# %%
df.to_csv('data/heart_disease_cleaned.csv',index=False)
