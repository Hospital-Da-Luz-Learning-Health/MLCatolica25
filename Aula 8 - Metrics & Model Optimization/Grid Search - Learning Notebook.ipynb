# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # Start

# %%
data_url = 'https://raw.githubusercontent.com/Hospital-Da-Luz-Learning-Health/MLCatolica24/main/Aula%208%20-%20Metrics%20%26%20Model%20Optimization/data/liver_disease.csv'
df = pd.read_csv(data_url, index_col = 'id')
df.head(3)
df.shape
# Out:
#       Age  Gender        BMI  AlcoholConsumption  Smoking  GeneticRisk  \
# id
# 572    75       1  32.960731           10.911642        0            0
# 125    20       1  30.298513            9.417347        0            0
# 1553   21       1  33.230869            1.685287        1            1
#
#       PhysicalActivity  Diabetes  Hypertension  LiverFunctionTest  Diagnosis
# id
# 572           8.930014         0             1          89.950963          1
# 125           1.484017         0             0          75.777573          1
# 1553          3.411027         0             0          69.226081          1
# (804, 11)

# %%
X = df.drop(columns='Diagnosis')
y = df['Diagnosis']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state=42, stratify=y)

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# Lookup the parameters in the [documentation](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html). Or ask chatgpt to help you build a parameter grid for logistic regression from sklearn

# %%
param_grid = {
    'C': np.logspace(-4, 4, 20),
    'penalty': ['l1', 'l2'],
    'class_weight': ['balanced', None],
    'solver': ['liblinear']
}

# %%
grid = GridSearchCV(LogisticRegression(), # your model
                    param_grid, #the parameter grid
                    cv=3, #how many folds do you want in your cross-validation
                    scoring='f1', # what scoring metric do you want. More here: https://scikit-learn.org/stable/modules/model_evaluation.html
                    verbose=1, # to show the messages during training
                    n_jobs=-1 # how many cores to use in your computer
                    )

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 80 candidates, totalling 240 fits
# /Users/simaonovais/miniconda3/envs/MLCatolica24/lib/python3.12/site-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/simaonovais/miniconda3/envs/MLCatolica24/lib/python3.12/site-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# GridSearchCV(cv=3, estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': array([1.00000000e-04, 2.63665090e-04, 6.95192796e-04, 1.83298071e-03,
#        4.83293024e-03, 1.27427499e-02, 3.35981829e-02, 8.85866790e-02,
#        2.33572147e-01, 6.15848211e-01, 1.62377674e+00, 4.28133240e+00,
#        1.12883789e+01, 2.97635144e+01, 7.84759970e+01, 2.06913808e+02,
#        5.45559478e+02, 1.43844989e+03, 3.79269019e+03, 1.00000000e+04]),
#                          'class_weight': ['balanced', None],
#                          'penalty': ['l1', 'l2'], 'solver': ['liblinear']},
#              scoring='f1', verbose=1)

# %%
results = pd.DataFrame(grid.cv_results_).sort_values('rank_test_score')
results.head(5)
results.shape
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time    param_C  \
# 49       0.001018      0.000046         0.000704        0.000019  11.288379
# 45       0.002224      0.000794         0.001629        0.000628   4.281332
# 53       0.003179      0.000951         0.001791        0.000246  29.763514
# 44       0.007166      0.000914         0.001409        0.000549   4.281332
# 40       0.005963      0.001568         0.001041        0.000037   1.623777
#
#    param_class_weight param_penalty param_solver  \
# 49           balanced            l2    liblinear
# 45           balanced            l2    liblinear
# 53           balanced            l2    liblinear
# 44           balanced            l1    liblinear
# 40           balanced            l1    liblinear
#
#                                                params  split0_test_score  \
# 49  {'C': 11.288378916846883, 'class_weight': 'bal...           0.318182
# 45  {'C': 4.281332398719396, 'class_weight': 'bala...           0.341463
# 53  {'C': 29.763514416313132, 'class_weight': 'bal...           0.318182
# 44  {'C': 4.281332398719396, 'class_weight': 'bala...           0.311111
# 40  {'C': 1.623776739188721, 'class_weight': 'bala...           0.325581
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 49           0.352941           0.384615         0.351913        0.027131
# 45           0.339623           0.370370         0.350485        0.014081
# 53           0.360000           0.370370         0.349517        0.022558
# 44           0.360000           0.370370         0.347160        0.025840
# 40           0.326531           0.384615         0.345576        0.027608
#
#     rank_test_score
# 49                1
# 45                2
# 53                3
# 44                4
# 40                5
# (80, 15)

# %% [markdown]
# ## Interpreting what features made the best models (optional)

# %%
features = results.filter(like='param_')
features = pd.get_dummies(features)
target = results['mean_test_score']

# %%
features.head(3)
# Out:
#       param_C  param_class_weight_balanced  param_penalty_l1  \
# 49  11.288379                         True             False
# 45   4.281332                         True             False
# 53  29.763514                         True             False
#
#     param_penalty_l2  param_solver_liblinear
# 49              True                    True
# 45              True                    True
# 53              True                    True

# %%
target.head(3)
# Out:
# 49    0.351913
# 45    0.350485
# 53    0.349517
# Name: mean_test_score, dtype: float64

# %% [markdown]
# ### Using Linear Regression

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(features, target)

pd.Series(data=model.coef_, index=features.columns).sort_values(ascending=False).to_frame('Coeficient Value')
# Out:
# LinearRegression()
#                              Coeficient Value
# param_class_weight_balanced          0.142681
# param_penalty_l1                     0.001231
# param_C                              0.000021
# param_solver_liblinear               0.000000
# param_penalty_l2                    -0.001231

# %% [markdown]
# Seems that only the hyperparameter `class_weight` set as `balanced` linearly affects the model (in this case, positively)

# %% [markdown]
# ### Using Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor(max_depth=3)

model.fit(features, target)

pd.Series(data=model.feature_importances_, index=features.columns).sort_values(ascending=False).to_frame('Feature Importance')
# Out:
# DecisionTreeRegressor(max_depth=3)
#                              Feature Importance
# param_C                                0.698007
# param_class_weight_balanced            0.301993
# param_penalty_l1                       0.000000
# param_penalty_l2                       0.000000
# param_solver_liblinear                 0.000000

# %% [markdown]
# # Decision Tree

# %% [markdown]
# Lookup the parameters in the [documentation](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html). Or ask chatgpt to help you build a parameter grid for logistic regression from sklearn

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
param_grid = {
    'max_depth': [3, 5, 7, 9],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

# %%
grid = GridSearchCV(DecisionTreeClassifier(), # your model
                    param_grid, #the parameter grid
                    cv=3, #how many folds do you want in your cross-validation
                    scoring='f1', # what scoring metric do you want. More here: https://scikit-learn.org/stable/modules/model_evaluation.html
                    verbose=1, # to show the messages during training
                    n_jobs=-1 # how many cores to use in your computer
                    )

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 108 candidates, totalling 324 fits
# /Users/simaonovais/miniconda3/envs/MLCatolica24/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 108 fits failed out of a total of 324.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/simaonovais/miniconda3/envs/MLCatolica24/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/simaonovais/miniconda3/envs/MLCatolica24/lib/python3.12/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/Users/simaonovais/miniconda3/envs/MLCatolica24/lib/python3.12/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/simaonovais/miniconda3/envs/MLCatolica24/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 48 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/simaonovais/miniconda3/envs/MLCatolica24/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/simaonovais/miniconda3/envs/MLCatolica24/lib/python3.12/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/Users/simaonovais/miniconda3/envs/MLCatolica24/lib/python3.12/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/simaonovais/miniconda3/envs/MLCatolica24/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/simaonovais/miniconda3/envs/MLCatolica24/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1052: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.11111111 0.21445221 0.08333333
#  0.20454545 0.05555556 0.14017094 0.08888889 0.15250545 0.13650794
#  0.06060606 0.3342447  0.2034632  0.17855478 0.19413919 0.0952381
#  0.         0.08333333 0.                nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.04444444 0.06666667 0.08888889 0.04166667 0.23310023 0.19096459
#  0.15       0.18888889 0.15555556 0.16081871 0.27467219 0.12727273
#  0.13333333 0.23093682 0.21367521 0.07843137 0.18787879 0.22021116
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.16666667 0.1957265  0.21060606
#  0.20512821 0.11851852 0.2202381  0.2202381  0.16923077 0.2275641
#  0.22161172 0.08333333 0.26923077 0.22727273 0.35930736 0.08888889
#  0.17855478 0.1025641  0.20740741        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.24951267 0.1978022  0.         0.26714201 0.08222222 0.23597884
#  0.27200577 0.15384615 0.15555556 0.27200577 0.2        0.24444444
#  0.25620915 0.05555556 0.18518519 0.21010101 0.05555556 0.04444444]
#   warnings.warn(
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [3, 5, 7, 9],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='f1', verbose=1)

# %%
results = pd.DataFrame(grid.cv_results_).sort_values('rank_test_score')
results.head(5)
results.shape
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 76       0.000636      0.000069         0.000857        0.000097
# 19       0.006600      0.008519         0.005671        0.007024
# 46       0.000571      0.000008         0.000695        0.000007
# 96       0.000817      0.000059         0.000812        0.000021
# 99       0.000754      0.000033         0.000782        0.000043
#
#     param_max_depth param_max_features  param_min_samples_leaf  \
# 76                7               log2                       2
# 19                3               log2                       1
# 46                5               log2                       1
# 96                9               sqrt                       4
# 99                9               log2                       1
#
#     param_min_samples_split  \
# 76                        5
# 19                        5
# 46                        5
# 96                        2
# 99                        2
#
#                                                params  split0_test_score  \
# 76  {'max_depth': 7, 'max_features': 'log2', 'min_...           0.363636
# 19  {'max_depth': 3, 'max_features': 'log2', 'min_...           0.210526
# 46  {'max_depth': 5, 'max_features': 'log2', 'min_...           0.190476
# 96  {'max_depth': 9, 'max_features': 'sqrt', 'min_...           0.285714
# 99  {'max_depth': 9, 'max_features': 'log2', 'min_...           0.166667
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 76           0.428571           0.285714         0.359307        0.058401
# 19           0.428571           0.363636         0.334245        0.091411
# 46           0.347826           0.285714         0.274672        0.064711
# 96           0.166667           0.363636         0.272006        0.080995
# 99           0.363636           0.285714         0.272006        0.080995
#
#     rank_test_score
# 76                1
# 19                2
# 46                3
# 96                4
# 99                4
# (108, 15)

# %% [markdown]
# # Picking the best model

# %%
best_model = grid.best_estimator_

# %% [markdown]
# Using that model to estimate performance on a test set

# %%
y_pred = best_model.predict(X_test)

f1 = best_model.score(X_test, y_test)

# %%
f1
# Out:
# 0.9397163120567376

# %% [markdown]
# # RandomSearch

# %% [markdown]
# When your dataset is too large, searching a very large hyperparameter space becomes unfeasable

# %%
param_grid = {
    'max_depth': [3, 5, 7, 9],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

# %%
# init random search
grid = RandomizedSearchCV(DecisionTreeClassifier(), # your model
                    param_grid, #the parameter grid
                    cv=3, #how many folds do you want in your cross-validation
                    scoring='f1', # what scoring metric do you want. More here: https://scikit-learn.org/stable/modules/model_evaluation.html
                    verbose=1, # to show the messages during training
                    n_jobs=-1, # how many cores to use in your computer
                    n_iter=20, # how many iterations do you want to do,
                    random_state=40
                    )

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# /Users/simaonovais/miniconda3/envs/MLCatolica24/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 18 fits failed out of a total of 60.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/simaonovais/miniconda3/envs/MLCatolica24/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/simaonovais/miniconda3/envs/MLCatolica24/lib/python3.12/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/Users/simaonovais/miniconda3/envs/MLCatolica24/lib/python3.12/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/simaonovais/miniconda3/envs/MLCatolica24/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/simaonovais/miniconda3/envs/MLCatolica24/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/simaonovais/miniconda3/envs/MLCatolica24/lib/python3.12/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/Users/simaonovais/miniconda3/envs/MLCatolica24/lib/python3.12/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/simaonovais/miniconda3/envs/MLCatolica24/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/simaonovais/miniconda3/envs/MLCatolica24/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1052: UserWarning: One or more of the test scores are non-finite: [0.17676768 0.11477411 0.12121212 0.18888889        nan 0.06060606
#  0.03921569 0.08333333        nan        nan        nan 0.11616162
#  0.         0.12535613 0.1577342  0.15873016 0.11111111 0.23885918
#         nan        nan]
#   warnings.warn(
# RandomizedSearchCV(cv=3, estimator=DecisionTreeClassifier(), n_iter=20,
#                    n_jobs=-1,
#                    param_distributions={'max_depth': [3, 5, 7, 9],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10]},
#                    random_state=40, scoring='f1', verbose=1)

# %%
results = pd.DataFrame(grid.cv_results_).sort_values('rank_test_score')
results.head(5)
results.shape
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 17       0.001122      0.000486         0.001406        0.000364
# 3        0.001063      0.000332         0.001039        0.000198
# 0        0.000936      0.000101         0.001064        0.000263
# 15       0.000635      0.000030         0.000745        0.000020
# 14       0.000989      0.000306         0.000811        0.000052
#
#     param_min_samples_split  param_min_samples_leaf param_max_features  \
# 17                        2                       4               log2
# 3                         2                       2               sqrt
# 0                         2                       4               sqrt
# 15                        2                       2               log2
# 14                        2                       1               log2
#
#     param_max_depth                                             params  \
# 17                5  {'min_samples_split': 2, 'min_samples_leaf': 4...
# 3                 9  {'min_samples_split': 2, 'min_samples_leaf': 2...
# 0                 3  {'min_samples_split': 2, 'min_samples_leaf': 4...
# 15                5  {'min_samples_split': 2, 'min_samples_leaf': 2...
# 14                5  {'min_samples_split': 2, 'min_samples_leaf': 1...
#
#     split0_test_score  split1_test_score  split2_test_score  mean_test_score  \
# 17           0.352941           0.000000           0.363636         0.238859
# 3            0.166667           0.400000           0.000000         0.188889
# 0            0.166667           0.000000           0.363636         0.176768
# 15           0.000000           0.333333           0.142857         0.158730
# 14           0.133333           0.117647           0.222222         0.157734
#
#     std_test_score  rank_test_score
# 17        0.168955                1
# 3         0.164054                2
# 0         0.148626                3
# 15        0.136545                4
# 14        0.046047                5
# (20, 15)
