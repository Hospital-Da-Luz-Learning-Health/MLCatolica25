# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Options

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Code

# %%
dataset_source = 'https://raw.githubusercontent.com/Hospital-Da-Luz-Learning-Health/MLCatolica24/main/Final%20Project/data/data.csv'
df = pd.read_csv(dataset_source)
df.head(3)
df.shape
# Out:
#    encounter_id  patient_nbr             race  gender      age  \
# 0       2278392     50941692        Caucasian  Female   [0-10)
# 1        149190     24691500        Caucasian  Female  [10-20)
# 2         64410     55584504  AfricanAmerican  Female  [20-30)
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
#
#    time_in_hospital         medical_specialty  num_lab_procedures  \
# 0                 1  Pediatrics-Endocrinology                  41
# 1                 3                   Unknown                  59
# 2                 2                   Unknown                  11
#
#    num_procedures  num_medications  number_outpatient  number_emergency  \
# 0               0                1                  0                 0
# ...

# %%
df.shape
# Out:
# (81176, 27)

# %%
df.describe().transpose()
# Out:
#                             count          mean           std      min  \
# encounter_id              81176.0  1.650091e+08  1.025885e+08  12522.0
# patient_nbr               81176.0  5.475543e+07  3.936887e+07    135.0
# admission_type_id         81176.0  2.026941e+00  1.448579e+00      1.0
# discharge_disposition_id  81176.0  3.695427e+00  5.254433e+00      1.0
# admission_source_id       81176.0  5.753080e+00  4.077598e+00      1.0
# time_in_hospital          81176.0  4.398295e+00  2.985002e+00      1.0
# num_lab_procedures        81176.0  4.309211e+01  1.967169e+01      1.0
# num_procedures            81176.0  1.338955e+00  1.706029e+00      0.0
# num_medications           81176.0  1.601600e+01  8.116236e+00      1.0
# number_outpatient         81176.0  3.678550e-01  1.250791e+00      0.0
# number_emergency          81176.0  1.892678e-01  7.894601e-01      0.0
# number_inpatient          81176.0  6.278333e-01  1.243318e+00      0.0
# ...

# %%
df['gender'] = df['gender'].map({'Female': 0, 'Male': 1})

# %%
df['gender'].value_counts()
# Out:
# gender
# 0.0    43720
# 1.0    37453
# Name: count, dtype: int64

# %%
df['race'].value_counts()
# Out:
# race
# Caucasian          60802
# AfricanAmerican    15261
# Unknown             1803
# Hispanic            1635
# Other               1181
# Asian                494
# Name: count, dtype: int64

# %%
df['A1Cresult'].value_counts()
# Out:
# A1Cresult
# Unknown    67537
# >8          6588
# Norm        4019
# >7          3032
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age  \
# 0       2278392     50941692        Caucasian     0.0   [0-10)
# 1        149190     24691500        Caucasian     0.0  [10-20)
# 2         64410     55584504  AfricanAmerican     0.0  [20-30)
# 3        500364     13161366        Caucasian     1.0  [30-40)
# 4         16680     57700530        Caucasian     1.0  [40-50)
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital         medical_specialty  num_lab_procedures  \
# 0                 1  Pediatrics-Endocrinology                  41
# ...

# %%
df['diabetes_exists'] = df[['diag_1', 'diag_2', 'diag_3']].apply(lambda x: 'yes' if any(val in [49, 50] for val in x) else 'no', axis=1)

# %%
df['diabetes_exists'].value_counts()
# Out:
# diabetes_exists
# no     50767
# yes    30409
# Name: count, dtype: int64

# %%
hists = df.hist(bins=35, figsize=(15,15))
plt.show()
